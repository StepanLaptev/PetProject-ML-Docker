# %% [markdown]
# # Import

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, \
f1_score, log_loss,plot_confusion_matrix, confusion_matrix
from sklearn.preprocessing import label_binarize, LabelEncoder

import joblib

import optuna
from optuna.visualization.matplotlib import plot_param_importances
from optuna.visualization import plot_optimization_history

import warnings
from warnings import simplefilter
warnings.filterwarnings("ignore")
simplefilter("ignore", category=RuntimeWarning)

# %%
config_path = 'E:/Pet_project/MLOps/Pet_MLOps/config/parameters.yml'
config = yaml.load(open(config_path), Loader=yaml.FullLoader)

preprocess = config['preprocessing']
training = config['train']
evaluate = config['evaluate']


'''# check columns with train
column_sequence_path = preproces['unique_values_path']
with open(column_sequence_path) as json_file:
    column_sequence = json.load(json_file)'''
# Out:
# "# check columns with train\ncolumn_sequence_path = preproces['unique_values_path']\nwith open(column_sequence_path) as json_file:\n    column_sequence = json.load(json_file)"

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_test = pd.read_csv(evaluate['predict_path'])
data_test.head()
# Out:
#            Tour_ID         country age_group    travel_with  total_female  \
# 0  tour_idynufedne           KOREA     25-44          Alone           0.0
# 1  tour_id9r3y5moe  UNITED KINGDOM     45-64  With Children           1.0
# 2  tour_idf6itml6g           ITALY     25-44    With Spouse           1.0
# 3  tour_id99u4znru           KENYA     25-44          Alone           0.0
# 4  tour_idj4i9urbx          ZAMBIA     25-44          Alone           0.0
#
#    total_male               purpose       main_activity  \
# 0         1.0  Leisure and Holidays     Widlife Tourism
# 1         1.0  Leisure and Holidays  Conference Tourism
# 2         1.0  Leisure and Holidays       Beach Tourism
# 3         1.0                 Other       Beach Tourism
# 4         1.0              Business     Widlife Tourism
#
#                    info_source tour_arrangement package_transport_int  \
# 0                       Others      Independent                    No
# 1  Travel agent, tour operator     Package Tour                   Yes
# 2  Travel agent, tour operator     Package Tour                   Yes
# 3               Radio, TV, Web      Independent                    No
# 4               Radio, TV, Web      Independent                    No
#
#   package_accomodation package_food package_transport_tz package_sightseeing  \
# 0                   No           No                   No                  No
# 1                  Yes          Yes                  Yes                 Yes
# 2                  Yes           No                  Yes                  No
# 3                   No           No                   No                  No
# 4                   No           No                   No                  No
#
#   package_guided_tour package_insurance  night_mainland  night_zanzibar  \
# 0                  No                No               7               4
# 1                 Yes               Yes               7               0
# 2                  No                No               0               6
# 3                  No                No               3               4
# 4                  No                No               6               0
#
#   first_trip_tz
# 0           Yes
# 1           Yes
# 2           Yes
# 3            No
# 4            No

# %% [markdown]
# # Preprocessing

# %%
def lower_case(data: pd.DataFrame, columns: list):
    '''
    приведение к одному регистру
    :param data: датасет
    :param columns: признаки, значения которых необходимо привести к одному регистру
    '''
    for i in columns:
        data[i] = data[i].str.lower()

def correct_mistake(data: pd.DataFrame, map_dict_mistake: dict):
    '''
    Замена значений в датасете
    :param data: датасет
    :param map_dict_mistake: словарь с признаками и значениями
    :return: датасет
    '''
    return data.replace(map_dict_mistake)

def filling_in_gaps(data:pd.DataFrame):
    '''
    заполнение пропусков
    :param data: датасет
    '''
    list_data_columns = data.isna().sum().reset_index().rename(columns={
        'index': 'col_name',
        0: 'cnt'
    })

    list_columns_zero = list(
        (list_data_columns[list_data_columns.iloc[:, 1] != 0]['col_name']))

    for i in list_columns_zero:
        if data[i].dtype == 'int' or data[i].dtype == 'float':
            data[i].fillna(data[i].median(), inplace=True)
        else:
            data[i].fillna('None', inplace=True)

    return data.isna().sum()

def func_map_values(data:pd.DataFrame, names_cols: dict):
    '''
    замена значений в датасете
    :param data: датасет
    :param names_cols: список признаков
    '''
    return data.replace(names_cols)

def symbol_correct(data:pd.DataFrame, names_cols: list):
    '''
    замена пробелов и запятых символом "_"
    :param data: датасет
    :param names_cols: список признаков, в значениях которых встречаются пробелы и запятые
    '''
    for col in names_cols:
        data[col].replace(' ', '_', regex=True, inplace=True)
        data[col].replace(',', '', regex=True, inplace=True)
        
def correct_types(data: pd.DataFrame, change_type_columns: dict):
    """
    Преобразование признаков в заданный тип данных
    :param data: датасет
    :param change_type_columns: словарь с признаками и типами данных
    :return:
    """
    return data.astype(change_type_columns, errors="raise")

# %%
def pipeline(data:pd.DataFrame, **kwargs):
    '''
    сбор функций для коректировки датасета
    :param data: датасет
    return: датасет
    '''
    # удаление признаков
    data.drop(columns=kwargs['drop_column'], axis=1, inplace=True)
    
    # приведение к одному регистру
    lower_case(data=data, columns=kwargs['lower_columns'])
    
    # исправление орфографических ошибок
    data = correct_mistake(data=data, map_dict_mistake=kwargs['correct_values'])
    
    # заполнение пропусков
    filling_in_gaps(data=data)
    
    # перевод признаков типа bool в int и замена значений в признаке age_group
    data = func_map_values(data=data, names_cols=kwargs['map_func_for_columns'])
    
    # замена пробелов и запятых в датасете на "_"
    symbol_correct(data=data, names_cols=kwargs['columns_symbol_correct'])
    
    # преобразование признаков в заданный тип
    assert isinstance(
        kwargs["change_type_columns"], dict
    ), "Подайте тип данных в формате dict"
    data = correct_types(data=data, change_type_columns=kwargs['change_type_columns'])
    
    return data

# %%
data_test = pipeline(data=data_test, **preprocess)
data_test.head()
# Out:
#           country age_group    travel_with  total_female  total_male  \
# 0           korea  25_to_44          Alone           0.0         1.0
# 1  united_kingdom  45_to_64  With_Children           1.0         1.0
# 2           italy  25_to_44    With_Spouse           1.0         1.0
# 3           kenya  25_to_44          Alone           0.0         1.0
# 4          zambia  25_to_44          Alone           0.0         1.0
#
#                 purpose       main_activity                 info_source  \
# 0  Leisure_and_Holidays    Wildlife_Tourism                      Others
# 1  Leisure_and_Holidays  Conference_Tourism  Travel_agent_tour_operator
# 2  Leisure_and_Holidays       Beach_Tourism  Travel_agent_tour_operator
# 3                 Other       Beach_Tourism                Radio_TV_Web
# 4              Business    Wildlife_Tourism                Radio_TV_Web
#
#   tour_arrangement  package_transport_int  package_accomodation  package_food  \
# 0      Independent                      0                     0             0
# 1     Package_Tour                      1                     1             1
# 2     Package_Tour                      1                     1             0
# 3      Independent                      0                     0             0
# 4      Independent                      0                     0             0
#
#    package_transport_tz  package_sightseeing  package_guided_tour  \
# 0                     0                    0                    0
# 1                     1                    1                    1
# 2                     1                    0                    0
# 3                     0                    0                    0
# 4                     0                    0                    0
#
#    package_insurance  night_mainland  night_zanzibar  first_trip_tz
# 0                  0               7               4              1
# 1                  1               7               0              1
# 2                  0               0               6              1
# 3                  0               3               4              0
# 4                  0               6               0              0

# %% [markdown]
# # Evaluate

# %%
# обращение к сохраненной модели
saved_model = joblib.load(training['model_path'])
# предсказание классов на test dataset
data_test['predict'] = saved_model.predict(data_test)

# %%
mapping = {'High_Cost': 0,
 'Higher_Cost': 1,
 'Highest_Cost': 2,
 'Low_Cost': 3,
 'Lower_Cost': 4,
 'Normal_Cost': 5}
map_reverse = {g:i for i, g in mapping.items()}

# %%
data_test['predict'] = data_test['predict'].map(map_reverse)
data_test.head(20)
# Out:
#                      country age_group                   travel_with  \
# 0                      korea  25_to_44                         Alone
# 1             united_kingdom  45_to_64                 With_Children
# 2                      italy  25_to_44                   With_Spouse
# 3                      kenya  25_to_44                         Alone
# 4                     zambia  25_to_44                         Alone
# 5                     uganda  45_to_64                         Alone
# 6                      italy  45_to_64      With_Spouse_and_Children
# 7                     zambia  25_to_44                         Alone
# 8             united_kingdom  45_to_64                   With_Spouse
# 9            the_netherlands  25_to_44                         Alone
# 10                      oman  25_to_44      With_Spouse_and_Children
# 11                  zimbabwe  25_to_44                         Alone
# 12                   belgium  45_to_64                   With_Spouse
# 13                       drc  45_to_64                 With_Children
# 14  united_states_of_america   more_65                          None
# 15           the_netherlands  25_to_44                         Alone
# 16                     italy  45_to_64                   With_Spouse
# 17                     kenya  45_to_64                         Alone
# 18                    france  25_to_44                   With_Spouse
# 19                    canada  25_to_44  With_Other_Friends/Relatives
#
#     total_female  total_male                         purpose  \
# 0            0.0         1.0            Leisure_and_Holidays
# 1            1.0         1.0            Leisure_and_Holidays
# 2            1.0         1.0            Leisure_and_Holidays
# 3            0.0         1.0                           Other
# 4            0.0         1.0                        Business
# 5            0.0         1.0  Visiting_Friends_and_Relatives
# 6            1.0         2.0            Leisure_and_Holidays
# 7            0.0         1.0                        Business
# 8            1.0         1.0            Leisure_and_Holidays
# 9            0.0         1.0                        Business
# 10           4.0         2.0  Visiting_Friends_and_Relatives
# 11           0.0         1.0                        Business
# 12           1.0         1.0            Leisure_and_Holidays
# 13           1.0         1.0  Visiting_Friends_and_Relatives
# 14           1.0         0.0  Visiting_Friends_and_Relatives
# 15           0.0         1.0            Leisure_and_Holidays
# 16           1.0         1.0            Leisure_and_Holidays
# 17           0.0         1.0         Meetings_and_Conference
# 18           1.0         1.0            Leisure_and_Holidays
# 19           1.0         1.0  Visiting_Friends_and_Relatives
#
#          main_activity                 info_source tour_arrangement  \
# 0     Wildlife_Tourism                      Others      Independent
# 1   Conference_Tourism  Travel_agent_tour_operator     Package_Tour
# 2        Beach_Tourism  Travel_agent_tour_operator     Package_Tour
# 3        Beach_Tourism                Radio_TV_Web      Independent
# 4     Wildlife_Tourism                Radio_TV_Web      Independent
# 5        Beach_Tourism           Friends_relatives      Independent
# 6        Beach_Tourism  Travel_agent_tour_operator     Package_Tour
# 7        Beach_Tourism           Friends_relatives      Independent
# 8     Wildlife_Tourism           Friends_relatives     Package_Tour
# 9     Wildlife_Tourism           Friends_relatives      Independent
# 10       Beach_Tourism                      Others      Independent
# 11  Conference_Tourism  Travel_agent_tour_operator      Independent
# 12    Wildlife_Tourism  Travel_agent_tour_operator     Package_Tour
# 13    Cultural_Tourism           Friends_relatives      Independent
# 14    Wildlife_Tourism           Friends_relatives     Package_Tour
# 15  Conference_Tourism           Friends_relatives      Independent
# 16       Beach_Tourism  Travel_agent_tour_operator     Package_Tour
# 17  Conference_Tourism                      Others      Independent
# 18    Wildlife_Tourism  Travel_agent_tour_operator     Package_Tour
# 19    Wildlife_Tourism           Friends_relatives      Independent
#
#     package_transport_int  package_accomodation  package_food  \
# 0                       0                     0             0
# 1                       1                     1             1
# 2                       1                     1             0
# 3                       0                     0             0
# 4                       0                     0             0
# 5                       0                     0             0
# 6                       1                     1             1
# 7                       0                     0             0
# 8                       0                     1             1
# 9                       0                     0             0
# 10                      0                     0             0
# 11                      0                     0             0
# 12                      1                     1             1
# 13                      0                     0             0
# 14                      0                     1             1
# 15                      0                     0             0
# 16                      1                     1             1
# 17                      0                     0             0
# 18                      1                     1             1
# 19                      0                     0             0
#
#     package_transport_tz  package_sightseeing  package_guided_tour  \
# 0                      0                    0                    0
# 1                      1                    1                    1
# 2                      1                    0                    0
# 3                      0                    0                    0
# 4                      0                    0                    0
# 5                      0                    0                    0
# 6                      1                    0                    1
# 7                      0                    0                    0
# 8                      1                    1                    0
# 9                      0                    0                    0
# 10                     0                    0                    0
# 11                     0                    0                    0
# 12                     0                    0                    1
# 13                     0                    0                    0
# 14                     1                    1                    1
# 15                     0                    0                    0
# 16                     1                    0                    0
# 17                     0                    0                    0
# 18                     1                    0                    0
# 19                     0                    0                    0
#
#     package_insurance  night_mainland  night_zanzibar  first_trip_tz  \
# 0                   0               7               4              1
# 1                   1               7               0              1
# 2                   0               0               6              1
# 3                   0               3               4              0
# 4                   0               6               0              0
# 5                   0              23               0              0
# 6                   1               0              14              1
# 7                   0               6               0              0
# 8                   0               4               0              1
# 9                   0               2               0              0
# 10                  0              91              14              0
# 11                  0               2               0              0
# 12                  0               6               4              1
# 13                  0               2               0              0
# 14                  0              11               2              1
# 15                  0              13               0              1
# 16                  1               0               7              1
# 17                  0               6               0              0
# 18                  0               9               5              0
# 19                  0              15               6              1
#
#         predict
# 0   Normal_Cost
# 1   Higher_Cost
# 2     High_Cost
# 3   Normal_Cost
# 4   Normal_Cost
# 5    Lower_Cost
# 6   Higher_Cost
# 7   Normal_Cost
# 8   Higher_Cost
# 9    Lower_Cost
# 10  Higher_Cost
# 11   Lower_Cost
# 12  Higher_Cost
# 13   Lower_Cost
# 14  Higher_Cost
# 15  Normal_Cost
# 16    High_Cost
# 17  Normal_Cost
# 18  Higher_Cost
# 19  Normal_Cost
